# %% [markdown]
# # Ionospheric phase in InSAR data

# %% [markdown]
# The interferometric phase of repeat-pass InSAR interferograms ($\Delta\phi$)
# formed from two SAR acquisitions at $t_i$ and $t_j$ contains different components as follows:
#
# $\Delta\phi = \Delta\phi_{displacement} + \Delta\phi_{geometry} + \Delta\phi_{troposphere} + \Delta\phi_{ionosphere}  + \Delta\phi_{noise}$
#
# * $\Delta\phi_{displacement}$: ground displacement
#
# * $\Delta\phi_{geometry}$: geometrical phase (topography + earht curvature)
#
# * $\Delta\phi_{troposphere}$: tropospheric delay
#
# * $\Delta\phi_{ionosphere}$: ionospheric delay
#
#
# The interferometric phase derived with repeat-pass interferometry, may be significantly affected by spatial and temporal variation of the number of free electrons in the ionosphere.
#
# In the ionosphere, highly energetic solar radiations such as
# extreme ultraviolet and X-ray radiation partially ionize the atmosphere’s neutral atoms and molecules forming a mixture of free electrons, ions, and neutral gas molecules around earth. The ionosphere extends approximately from altitudes of 60 to 1000 km, with a maximum electron density at around 300 km.
#
# Propagation of microwave signals through the ionosphere
# causes distortions in the InSAR data, including:
#
# * defocusing of SAR images
# * Faraday rotation
# * azimuth offsets (extra shift between SAR images in the satellite along-track (azimuth) direction)
# * range delay (or phase advance which can significantly bias the ground displacement signal)
#
#
# Ionospheric delay also introduces an extra phase component to the SAR interferograms, which if not compensated, decreases the accuracy of InSAR measurements of ground displacement. Along-track TEC gradients cause a phase gradient equivalent to an extra Doppler shift, which translates to a time shift in the azimuth direction. In other words, the ionospheric phase gradient introduces extra azimuth offsets between two SAR images that cannot be predicted with geometrical coregistration techniques.
#
# Ionosphere is a dispersive medium with respect to the
# microwave frequencies. In such a dispersive medium, the delay of the microwave signal is inversely proportional
# to the signal's frequency.

# %% [markdown]
# ![title](docs_iono/iono_1.png)

# %% [markdown]
# The dispersive property of ionosphere with respect to the microwave signal, provides an opportunity to separate ionospheric phase (which is dispersive) from non-dispersive phase components (ground displacement, troposphere and geometry). For this we need to have the interferograms at least at two different frequencies. Current and most future missions operate at a single center frequency. However, one can split the range bandwidth and form interferograms with slightly different center frequencies. These interferograms can be combined to estimate the ionospheric phase:

# %% [markdown]
# ![title](docs_iono/iono_2.png)

# %% [markdown]
# The impact of ionospheric phase on ground displacement derived from InSAR data is a function of TEC variations between two SAR acquisition dates and center frequencies at which the data has been acquired.
#
# TEC variation, is a function of:
# * geographic location (e.g., higher TEC at equatorial belt compared to mid-latitudes)
# * time of day (lower TEC at dusk-down time)
# * season (more TEC at summer hemisphere than winter hemisphere)
# * levels of geomagnetic and solar activities (higher TEC at solar maxima (with a cycle of 11 years))
#
# The ionospheric phase is larger at lower frequencies. Given the same variation of ionosphere TEC and a similar imaging geometry, ionospheric phase at L-band frequency (1.27 GHz) is
# * 3.9 times larger than S-band (2.5 GHz)
# * 18.1 times larger than C-band (5.405 GHz)
# * 57.7 times larger than X-band (9.65 GHz)
#
# Here is an example of the impact of ionosphere on InSAR data at equatorial belt:

# %% [markdown]
# ![title](docs_iono/iono_Maule.png)

# %% [markdown]
# stripmapApp allows to estimate ionospheric phase using the split range-spectrum technique. In the following we go back to the ALOS-1 interferogram which we processed in the stripmapApp session and will discuss the processing steps to estimate ionospheric phase.

# %% [markdown]
# # Prepare directories

# %% [markdown]
# Importing some python modules and setting up some variables:

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from osgeo import gdal

home_dir = '/scratch'
PROCESS_DIR = '/scratch/alor_2015_dsc_III'
DATA_DIR =  '/data/taramana_indonesia_2015_alos2/t022_dsc'

print("home directory: ", home_dir)
# Out:
# home directory:  /scratch

# %% [markdown]
# Check if the PROCESS_DIR and DATA_DIR already exist. If they don't exist, we create them:

# %% [markdown]
# cd to the PROCESS_DIR

# %%
os.chdir(PROCESS_DIR)

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Note :</b>
# In this notebook we will work on the same example shown on the stripmapApp notebook. Please make sure that you have gone through the stripmapApp notebook first and have sucessfuly run the processing steps up to split_range_spectrum. In the current notebook we will continue the steps from split_range_spectrum.
#
# </div>

# %% [markdown]
# # Setting up input xml files for processing with stripmapApp

# %% [markdown]
# Modify the stripmapApp.xml file as follows to introduce the "do split spectrum" and "do dispersive" options.

# %% [markdown]
# ### stripmapApp.xml

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <stripmapApp>
#   <component name="insar">
#     <property name="sensor name">ALOS</property>
#     <component name="reference">
#         <catalog>reference.xml</catalog>
#     </component>
#     <component name="secondary">
#         <catalog>secondary.xml</catalog>
#     </component>
#
#     <!--
#     <property name="demFilename">
#         <value>demLat_N18_N21_Lon_W156_W154.dem.wgs84</value>
#     </property>
#     -->
#     <property name="unwrapper name">icu</property>
#
#     <property name="do split spectrum">True</property>
#
#     <property name="do dispersive">True</property>
#
#
# </component>
# </stripmapApp>
# ```

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Note (do rubbersheeting) :</b>
# There is an optional step for rubbersheeting, which may be required when there is azimuth offsets introduced by ionospheric scintillation. If rubbersheeting is turned on, then a dense azimuth offset map is estimated based on amplitude cross-correlation and is used for more precise resampling.
#
# ```xml
#     <property name="do rubbersheeting">True</property>
# ```
# </div>

# %% [markdown]
# # stripmapApp processing steps

# %% [markdown]
# To see a full list of processing steps using stripmapApp try the help command:

# %%
# !stripmapApp.py --help --steps
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2023-01-04 14:37:21,073 - isce.insar - INFO - ISCE VERSION = 2.5.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210823, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.3, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210823, CURRENT_SVN_REVISION =
#
#     Insar Application:
#     Implements InSAR processing flow for a pair of scenes from
#     sensor raw data to geocoded, flattened interferograms.
#
# The currently supported sensors are:  ['ALOS', 'ALOS2', 'ALOS_SLC', 'COSMO_SKYMED', 'COSMO_SKYMED_SLC', 'ENVISAT', 'ENVISAT_SLC', 'ERS', 'ERS_ENVISAT', 'ERS_ENVISAT_SLC', 'ERS_SLC', 'ICEYE_SLC', 'KOMPSAT5', 'RADARSAT1', 'RADARSAT2', 'RISAT1', 'RISAT1_SLC', 'ROI_PAC', 'SAOCOM_SLC', 'SENTINEL1', 'SICD_RGZERO', 'TERRASARX', 'UAVSAR_HDF5_SLC', 'UAVSAR_POLSAR', 'UAVSAR_RPI', 'UAVSAR_STACK']
#
# Usages:
# stripmapApp.py <input-file.xml>
# stripmapApp.py --steps
# stripmapApp.py --help
# stripmapApp.py --help --steps
#
#
#     Insar Application:
#     Implements InSAR processing flow for a pair of scenes from
#     sensor raw data to geocoded, flattened interferograms.
#
# A description of the individual steps can be found in the README file
# and also in the ISCE.pdf document
#
# Command line options for steps processing are formed by
# combining the following three options as required:
#
# '--start=<step>', '--end=<step>', '--dostep=<step>'
#
# The step names are chosen from the following list:
#
# ['startup', 'preprocess', 'cropraw', 'formslc', 'cropslc']
# ['verifyDEM', 'topo', 'geo2rdr', 'coarse_resample', 'misregistration']
# ['refined_resample', 'dense_offsets', 'rubber_sheet_range', 'rubber_sheet_azimuth', 'fine_resample']
# ['split_range_spectrum', 'sub_band_resample', 'interferogram', 'sub_band_interferogram', 'filter']
# ['filter_low_band', 'filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band']
# ['ionosphere', 'geocode', 'geocodeoffsets', 'endup']
#
# If --start is missing, then processing starts at the first step.
# If --end is missing, then processing ends at the final step.
# If --dostep is used, then only the named step is processed.
#
# In order to use either --start or --dostep, it is necessary that a
# previous run was done using one of the steps options to process at least
# through the step immediately preceding the starting step of the current run.

# %% [markdown]
# The default setting of stripmapApp includes the following steps to generate a geocoded interferogram from raw data or SLC images:
#
# 'startup', 'preprocess',
# 'formslc',
# 'verifyDEM',
# 'topo',
# 'geo2rdr',
# 'coarse_resample',
# 'misregistration',
# 'refined_resample',
# 'interferogram',
# 'filter',
# 'unwrap',
# 'geocode'
#
# For ionospheric phase estimation, the following additional steps (in red) are required:
#
# 'startup', 'preprocess',
# 'formslc',
# 'verifyDEM',
# 'topo',
# 'geo2rdr',
# 'coarse_resample',
# 'misregistration',
# 'refined_resample',
# <span style="color:red">split_range_spectrum</span>,
# <span style="color:red">sub_band_resample</span>,
# 'interferogram',
# <span style="color:red">sub_band_interferogram</span>,
# 'filter',
# <span style="color:red">filter_low_band</span>,
# <span style="color:red">filter_high_band</span>,
# 'unwrap',
# <span style="color:red">unwrap_low_band</span>,
# <span style="color:red">unwrap_high_band</span>,
# <span style="color:red">ionosphere</span>,
# ,'geocode'
#
# Since the processing steps up to refined_resample, are common for the two workflows with or without ionospheric phase correction, then we need to only run the steps after refined_resample.

# %% [markdown]
# ### split_range_spectrum

# %% [markdown]
# At this step the range spectrum of the reference and secondary SLC images are split to two sub-bands. The sub-bands are chosen to be 1/3 of the spectrum common between reference and secondary images.

# %%
# !stripmapApp.py stripmapApp.xml --start=split_range_spectrum --end=split_range_spectrum
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:23:27,437 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:23:27,438 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:23:27,459 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step split_range_spectrum
# reference image range sampling rate: 34.930531904674595 MHz
# secondary image range sampling rate: 34.930531904674595 MHz
# reference image total range bandwidth: 24.90000000153456 MHz
# secondary image total range bandwidth: 24.90000000153456 MHz
# Bandwidth used for split spectrum: 24.90000000153456 MHz
# deviation of low-band's center frequency from full-band's center frequency: -8.30000000051152 MHz
# deviation of high-band's center frequency from full-band's center frequency: 8.30000000051152 MHz
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# splitting the range-spectrum of reference SLC
# Computed block size based on memory size = 1224 lines
# Block size = 1224 lines
# Total number of blocks to process: 18
# Processing with 8 threads
# sub-band center frequencies after adjustment:
# low-band: -8.3e+06
# high-band: 8.3e+06
# fftw_status: 1splitSpectrum processing time: 0.163769 mins
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# splitting the range-spectrum of secondary SLC
# Computed block size based on memory size = 1221 lines
# Block size = 1221 lines
# Total number of blocks to process: 18
# Processing with 8 threads
# sub-band center frequencies after adjustment:
# low-band: -8.3e+06
# high-band: 8.3e+06
# fftw_status: 1splitSpectrum processing time: 0.189047 mins
# API open (R): SplitSpectrum/lowBand/reference.slc
# API close:  SplitSpectrum/lowBand/reference.slc
# API open (R): SplitSpectrum/highBand/reference.slc
# API close:  SplitSpectrum/highBand/reference.slc
# API open (R): SplitSpectrum/lowBand/secondary.slc
# API close:  SplitSpectrum/lowBand/secondary.slc
# API open (R): SplitSpectrum/highBand/secondary.slc
# API close:  SplitSpectrum/highBand/secondary.slc
# Dumping the application's pickle object _insar to file  PICKLE/split_range_spectrum
# The remaining steps are (in order):  ['sub_band_resample', 'interferogram', 'sub_band_interferogram', 'filter', 'filter_low_band', 'filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']

# %% [markdown]
# A folder named "SplitSpectrum" with two subfolders, "lowband" and "highband" which contain the sub-band reference and secondary SLCs are added to the working directory.

# %%
ls SplitSpectrum
# Out:
# highBand/  lowBand/

# %%
ls SplitSpectrum/lowBand/
# Out:
# reference.slc      reference.slc.vrt  secondary.slc      secondary.slc.vrt
# reference.slc.hdr  reference.slc.xml  secondary.slc.hdr  secondary.slc.xml

# %%
ls SplitSpectrum/highBand/
# Out:
# reference.slc      reference.slc.vrt  secondary.slc      secondary.slc.vrt
# reference.slc.hdr  reference.slc.xml  secondary.slc.hdr  secondary.slc.xml

# %% [markdown]
# ### sub_band_resample

# %% [markdown]
# At this the sub-band secondary SLCs are coregistered to the sub-band reference SLCs. The range azimuth offsets required for coregistration are the same as the full band SLC.

# %%
# !stripmapApp.py stripmapApp.xml --start=sub_band_resample --end=sub_band_resample
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:23:51,563 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:23:51,565 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:23:51,587 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step sub_band_resample
# Using rubber in azimuth sheeted offsets for resampling sub-bands
# Using rubber in range sheeted offsets for resampling sub-bands
# 2022-01-13 11:23:51,723 - isce.insar.runResampleSubbandSlc - INFO - Resampling secondary SLC
# Polynomial Order: 0 - by - 2
# -5.06652e-05	-3.32273e-10	0
# Rubber sheeting in range is turned on, flattening the interferogram during interferogram formation
# False
# 2022-01-13 11:23:51,736 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 21349 which is the number of lines in the slc image.
# 2022-01-13 11:23:51,737 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 8732 which is the width of the slc image.
# GDAL open (R): SplitSpectrum/lowBand/secondary.slc.vrt
# API open (WR): coregisteredSlc/lowBand/secondary.slc
# No Range Carrier provided.
# Assuming zero range carrier.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# No Azimuth Carrier provided.
# Assuming zero azimuth carrier.
# Polynomial Order: 0 - by - 0
# -1.35541
# Polynomial Order: 0 - by - 0
# 1.27112
# GDAL open (R): offsets/range_sheet.off.vrt
# GDAL open (R): offsets/azimuth_sheet.off.vrt
# Polynomial Order: 0 - by - 2
# -5.06652e-05	-3.32273e-10	0
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#         8732  pixels
#        21349 lines
#
#  Output Image Dimensions:
#         8710 pixels
#        21348 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# -1.35541
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 1.27112
#  Reading in the image
#  At line         1000
#  At line         2000
#  At line         3000
#  At line         4000
#  At line         5000
#  At line         6000
#  At line         7000
#  At line         8000
#  At line         9000
#  At line        10000
#  At line        11000
#  At line        12000
#  At line        13000
#  At line        14000
#  At line        15000
#  At line        16000
#  At line        17000
#  At line        18000
#  At line        19000
#  At line        20000
#  At line        21000
#  Interpolating image
#  At line         1000
#  At line         2000
#  At line         3000
#  At line         4000
#  At line         5000
#  At line         6000
#  At line         7000
#  At line         8000
#  At line         9000
#  At line        10000
#  At line        11000
#  At line        12000
#  At line        13000
#  At line        14000
#  At line        15000
#  At line        16000
#  At line        17000
#  At line        18000
#  At line        19000
#  At line        20000
#  At line        21000
#  Elapsed time:    545.878906
# GDAL close: offsets/range_sheet.off.vrt
# GDAL close: offsets/azimuth_sheet.off.vrt
# GDAL close: SplitSpectrum/lowBand/secondary.slc.vrt
# API close:  coregisteredSlc/lowBand/secondary.slc
# API open (R): coregisteredSlc/lowBand/secondary.slc
# API close:  coregisteredSlc/lowBand/secondary.slc
# 2022-01-13 11:32:58,146 - isce.insar.runResampleSubbandSlc - INFO - Resampling secondary SLC
# Polynomial Order: 0 - by - 2
# -5.06652e-05	-3.32273e-10	0
# Rubber sheeting in range is turned on, flattening the interferogram during interferogram formation
# False
# 2022-01-13 11:32:58,157 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_LINES has been set to the default value 21349 which is the number of lines in the slc image.
# 2022-01-13 11:32:58,157 - isce.stdproc.resamp_slc - WARNING - The variable INPUT_WIDTH has been set to the default value 8732 which is the width of the slc image.
# GDAL open (R): SplitSpectrum/highBand/secondary.slc.vrt
# API open (WR): coregisteredSlc/highBand/secondary.slc
# No Range Carrier provided.
# Assuming zero range carrier.
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# No Azimuth Carrier provided.
# Assuming zero azimuth carrier.
# Polynomial Order: 0 - by - 0
# -1.35541
# Polynomial Order: 0 - by - 0
# 1.27112
# GDAL open (R): offsets/range_sheet.off.vrt
# GDAL open (R): offsets/azimuth_sheet.off.vrt
# Polynomial Order: 0 - by - 2
# -5.06652e-05	-3.32273e-10	0
#
#   << Resample one image to another image coordinates >>
#
#  Input Image Dimensions:
#         8732  pixels
#        21349 lines
#
#  Output Image Dimensions:
#         8710 pixels
#        21348 lines
#
#  Number of threads:            8
#  Complex data interpolation
#  Initializing Sinc interpolator
#  Azimuth Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range Carrier Poly
# Polynomial Order: 0 - by - 0
# 0
#  Range offsets poly
# Polynomial Order: 0 - by - 0
# -1.35541
#  Azimuth offsets poly
# Polynomial Order: 0 - by - 0
# 1.27112
#  Reading in the image
#  At line         1000
#  At line         2000
#  At line         3000
#  At line         4000
#  At line         5000
#  At line         6000
#  At line         7000
#  At line         8000
#  At line         9000
#  At line        10000
#  At line        11000
#  At line        12000
#  At line        13000
#  At line        14000
#  At line        15000
#  At line        16000
#  At line        17000
#  At line        18000
#  At line        19000
#  At line        20000
#  At line        21000
#  Interpolating image
#  At line         1000
#  At line         2000
#  At line         3000
#  At line         4000
#  At line         5000
#  At line         6000
#  At line         7000
#  At line         8000
#  At line         9000
#  At line        10000
#  At line        11000
#  At line        12000
#  At line        13000
#  At line        14000
#  At line        15000
#  At line        16000
#  At line        17000
#  At line        18000
#  At line        19000
#  At line        20000
#  At line        21000
#  Elapsed time:    31.1992188
# GDAL close: offsets/range_sheet.off.vrt
# GDAL close: offsets/azimuth_sheet.off.vrt
# GDAL close: SplitSpectrum/highBand/secondary.slc.vrt
# API close:  coregisteredSlc/highBand/secondary.slc
# API open (R): coregisteredSlc/highBand/secondary.slc
# API close:  coregisteredSlc/highBand/secondary.slc
# Dumping the application's pickle object _insar to file  PICKLE/sub_band_resample
# The remaining steps are (in order):  ['interferogram', 'sub_band_interferogram', 'filter', 'filter_low_band', 'filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']

# %% [markdown]
# After resampling the sub-band SLCs, the "lowband" and "highband" folders are added to the "coregisteredSlc" folder.

# %% [markdown]
# ### interferogram, sub-band interferogram

# %% [markdown]
# using the full-band SLCs, the low-band and the high-band SLCs, we get three interferograms at full band, low-band and the high-band of the range spectrum.

# %%
# !stripmapApp.py stripmapApp.xml --start=interferogram --end=sub_band_interferogram
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:33:30,450 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:33:30,451 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:33:30,471 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step interferogram
# 2022-01-13 11:33:30,514 - isce.insar.runInterferogram - INFO - igramSpectrum = full
# 2022-01-13 11:33:30,514 - isce.insar.runInterferogram - INFO - Generating interferogram
# incidence angle at the middle of the swath:  30.768479575844513
# Ground range resolution at the middle of the swath:  11.76755089528644
# azimuth and range looks:  8 3
# 2022-01-13 11:33:30,565 - isce.insar.runInterferogram - INFO - Interferogram directory interferogram already exists.
# GDAL open (R): reference_slc/reference.slc.vrt
# GDAL open (R): coregisteredSlc/fine_coreg.slc.vrt
# API open (WR): interferogram/topophase.flat.full
# API open (WR): interferogram/topophase.amp
# Rubbersheeting in range is on, removing flat-Earth phase
# Completed set State
#  Max threads used:            8
#  FFT length:        16384
#  wisdomFile, length =            0
#  Overall:       21348        1024          21
# API close:  interferogram/topophase.flat.full
# API close:  interferogram/topophase.amp
# API open (R): interferogram/topophase.flat.full
# API close:  interferogram/topophase.flat.full
# API open (R): interferogram/topophase.amp
# API close:  interferogram/topophase.amp
# offsets/range.off
# Multilooking interferogram/topophase.flat.full ...
# GDAL open (R): interferogram/topophase.flat.full.vrt
# API open (WR): interferogram/topophase.flat
# GDAL close: interferogram/topophase.flat.full.vrt
# API close:  interferogram/topophase.flat
# API open (R): interferogram/topophase.flat
# API close:  interferogram/topophase.flat
# Writing geotrans to VRT for interferogram/topophase.flat
# Multilooking interferogram/topophase.amp ...
# GDAL open (R): interferogram/topophase.amp.vrt
# API open (WR): interferogram/topophase.amp
# GDAL close: interferogram/topophase.amp.vrt
# API close:  interferogram/topophase.amp
# API open (R): interferogram/topophase.amp
# API close:  interferogram/topophase.amp
# Writing geotrans to VRT for interferogram/topophase.amp
# GDAL close: reference_slc/reference.slc.vrt
# GDAL close: coregisteredSlc/fine_coreg.slc.vrt
# GDAL open (R): reference_slc/reference.slc.vrt
# GDAL open (R): coregisteredSlc/fine_coreg.slc.vrt
# API open (WR): interferogram/topophase.cor.full
# 2022-01-13 11:33:58,787 - isce.mroipac.correlation - INFO - Calculating Correlation
# Operating on coregistered SLCs.
# Number of lines : 21348
# Number of pixels: 8710
# Processing with box size of 5
# # correlation weights (range,azimuth): 5 5
#
# range correlation weights:
# index,coefficient: -2  0.333333
# index,coefficient: -1  0.666667
# index,coefficient: 0  1
# index,coefficient: 1  0.666667
# index,coefficient: 2  0.333333
#
# azimuth correlation weights:
# index,coefficient:  -2  0.333333
# index,coefficient:  -1  0.666667
# index,coefficient:  0  1
# index,coefficient:  1  0.666667
# index,coefficient:  2  0.333333
# processing line: 21340ssing line: 5000line: 1450rocessing line: 1920ne: 2380cessing line: 2850: 3310ssing line: 37804240ing line: 471070g line: 5640line: 6570rocessing line: 7040ne: 7500cessing line: 7970: 8430ssing line: 89009360ing line: 9830ne: 10280ocessing line: 10730e: 11170cessing line: 11620: 12060essing line: 12510 12950ssing line: 1340013840sing line: 142904730ing line: 15180620ng line: 1607010g line: 169600 line: 17850line: 18740ine: 19630rocessing line: 20080ne: 20520ocessing line: 20970
# output lines:21348
# API close:  interferogram/topophase.cor.full
# GDAL close: reference_slc/reference.slc.vrt
# GDAL close: coregisteredSlc/fine_coreg.slc.vrt
# Multilooking interferogram/topophase.cor.full ...
# GDAL open (R): interferogram/topophase.cor.full.vrt
# API open (WR): interferogram/topophase.cor
# GDAL close: interferogram/topophase.cor.full.vrt
# API close:  interferogram/topophase.cor
# API open (R): interferogram/topophase.cor
# API close:  interferogram/topophase.cor
# Writing geotrans to VRT for interferogram/topophase.cor
# Multilooking geometry/lat.rdr.full ...
# GDAL open (R): geometry/lat.rdr.full.vrt
# API open (WR): geometry/lat.rdr
# GDAL close: geometry/lat.rdr.full.vrt
# API close:  geometry/lat.rdr
# API open (R): geometry/lat.rdr
# API close:  geometry/lat.rdr
# Writing geotrans to VRT for geometry/lat.rdr
# Multilooking geometry/lon.rdr.full ...
# GDAL open (R): geometry/lon.rdr.full.vrt
# API open (WR): geometry/lon.rdr
# GDAL close: geometry/lon.rdr.full.vrt
# API close:  geometry/lon.rdr
# API open (R): geometry/lon.rdr
# API close:  geometry/lon.rdr
# Writing geotrans to VRT for geometry/lon.rdr
# Multilooking geometry/los.rdr.full ...
# GDAL open (R): geometry/los.rdr.full.vrt
# API open (WR): geometry/los.rdr
# GDAL close: geometry/los.rdr.full.vrt
# API close:  geometry/los.rdr
# API open (R): geometry/los.rdr
# API close:  geometry/los.rdr
# Writing geotrans to VRT for geometry/los.rdr
# Dumping the application's pickle object _insar to file  PICKLE/interferogram
# The remaining steps are (in order):  ['sub_band_interferogram', 'filter', 'filter_low_band', 'filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']
# Running step sub_band_interferogram
# 2022-01-13 11:34:39,130 - isce.insar.runInterferogram - INFO - igramSpectrum = sub
# 2022-01-13 11:34:39,130 - isce.insar.runInterferogram - INFO - Generating sub-band interferograms
# azimuth and range looks:  8 3
# GDAL open (R): SplitSpectrum/lowBand/reference.slc.vrt
# GDAL open (R): coregisteredSlc/lowBand/secondary.slc.vrt
# API open (WR): interferogram/lowBand/topophase.flat.full
# API open (WR): interferogram/lowBand/topophase.amp
# Rubbersheeting in range is on, removing flat-Earth phase
# Completed set State
#  Max threads used:            8
#  FFT length:        16384
#  Overall:       21348        1024          21
# API close:  interferogram/lowBand/topophase.flat.full
# API close:  interferogram/lowBand/topophase.amp
# API open (R): interferogram/lowBand/topophase.flat.full
# API close:  interferogram/lowBand/topophase.flat.full
# API open (R): interferogram/lowBand/topophase.amp
# API close:  interferogram/lowBand/topophase.amp
# offsets/range.off
# Multilooking interferogram/lowBand/topophase.flat.full ...
# GDAL open (R): interferogram/lowBand/topophase.flat.full.vrt
# API open (WR): interferogram/lowBand/topophase.flat
# GDAL close: interferogram/lowBand/topophase.flat.full.vrt
# API close:  interferogram/lowBand/topophase.flat
# API open (R): interferogram/lowBand/topophase.flat
# API close:  interferogram/lowBand/topophase.flat
# Writing geotrans to VRT for interferogram/lowBand/topophase.flat
# Multilooking interferogram/lowBand/topophase.amp ...
# GDAL open (R): interferogram/lowBand/topophase.amp.vrt
# API open (WR): interferogram/lowBand/topophase.amp
# GDAL close: interferogram/lowBand/topophase.amp.vrt
# API close:  interferogram/lowBand/topophase.amp
# API open (R): interferogram/lowBand/topophase.amp
# API close:  interferogram/lowBand/topophase.amp
# Writing geotrans to VRT for interferogram/lowBand/topophase.amp
# GDAL close: SplitSpectrum/lowBand/reference.slc.vrt
# GDAL close: coregisteredSlc/lowBand/secondary.slc.vrt
# GDAL open (R): SplitSpectrum/highBand/reference.slc.vrt
# GDAL open (R): coregisteredSlc/highBand/secondary.slc.vrt
# API open (WR): interferogram/highBand/topophase.flat.full
# API open (WR): interferogram/highBand/topophase.amp
# Rubbersheeting in range is on, removing flat-Earth phase
# Completed set State
#  Max threads used:            8
#  FFT length:        16384
#  Overall:       21348        1024          21
# API close:  interferogram/highBand/topophase.flat.full
# API close:  interferogram/highBand/topophase.amp
# API open (R): interferogram/highBand/topophase.flat.full
# API close:  interferogram/highBand/topophase.flat.full
# API open (R): interferogram/highBand/topophase.amp
# API close:  interferogram/highBand/topophase.amp
# offsets/range.off
# Multilooking interferogram/highBand/topophase.flat.full ...
# GDAL open (R): interferogram/highBand/topophase.flat.full.vrt
# API open (WR): interferogram/highBand/topophase.flat
# GDAL close: interferogram/highBand/topophase.flat.full.vrt
# API close:  interferogram/highBand/topophase.flat
# API open (R): interferogram/highBand/topophase.flat
# API close:  interferogram/highBand/topophase.flat
# Writing geotrans to VRT for interferogram/highBand/topophase.flat
# Multilooking interferogram/highBand/topophase.amp ...
# GDAL open (R): interferogram/highBand/topophase.amp.vrt
# API open (WR): interferogram/highBand/topophase.amp
# GDAL close: interferogram/highBand/topophase.amp.vrt
# API close:  interferogram/highBand/topophase.amp
# API open (R): interferogram/highBand/topophase.amp
# API close:  interferogram/highBand/topophase.amp
# Writing geotrans to VRT for interferogram/highBand/topophase.amp
# GDAL close: SplitSpectrum/highBand/reference.slc.vrt
# GDAL close: coregisteredSlc/highBand/secondary.slc.vrt
# Dumping the application's pickle object _insar to file  PICKLE/sub_band_interferogram
# The remaining steps are (in order):  ['filter', 'filter_low_band', 'filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']

# %% [markdown]
# This will add the lowBand and highBand folders to the interferogram folder.

# %%
ls interferogram/lowBand/
# Out:
# filt_topophase.flat              phsig.cor
# filt_topophase.flat.sig          phsig.cor.vrt
# filt_topophase.flat.sig.vrt      phsig.cor.xml
# filt_topophase.flat.sig.xml      topophase.amp
# filt_topophase.flat.vrt          topophase.amp.vrt
# filt_topophase.flat.xml          topophase.amp.xml
# filt_topophase.unw               topophase.flat
# filt_topophase.unw.conncomp      topophase.flat.full
# filt_topophase.unw.conncomp.vrt  topophase.flat.full.vrt
# filt_topophase.unw.conncomp.xml  topophase.flat.full.xml
# filt_topophase.unw.vrt           topophase.flat.vrt
# filt_topophase.unw.xml           topophase.flat.xml

# %%
ls interferogram/highBand/
# Out:
# filt_topophase.flat              phsig.cor
# filt_topophase.flat.sig          phsig.cor.vrt
# filt_topophase.flat.sig.vrt      phsig.cor.xml
# filt_topophase.flat.sig.xml      topophase.amp
# filt_topophase.flat.vrt          topophase.amp.vrt
# filt_topophase.flat.xml          topophase.amp.xml
# filt_topophase.unw               topophase.flat
# filt_topophase.unw.conncomp      topophase.flat.full
# filt_topophase.unw.conncomp.vrt  topophase.flat.full.vrt
# filt_topophase.unw.conncomp.xml  topophase.flat.full.xml
# filt_topophase.unw.vrt           topophase.flat.vrt
# filt_topophase.unw.xml           topophase.flat.xml

# %% [markdown]
# ### filter_low_band, filter_high_band

# %% [markdown]
# To filter the full-band, low-band and high-band interferograms:

# %%
# !stripmapApp.py stripmapApp.xml --start=filter  --end=filter_high_band
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:35:31,272 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:35:31,273 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:35:31,293 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step filter
# 2022-01-13 11:35:31,336 - isce.insar.runFilter - INFO - Applying power-spectral filter
# 2022-01-13 11:35:31,336 - isce.insar.runFilter - INFO - Filtering the full-band interferogram
# GDAL open (R): interferogram/topophase.flat.vrt
# API open (WR): interferogram/filt_topophase.flat
# 2022-01-13 11:35:31,352 - isce.mroipac.filter - DEBUG - width: 2903
# 2022-01-13 11:35:31,352 - isce.mroipac.filter - DEBUG - length: 2668
# 2022-01-13 11:35:31,352 - isce.mroipac.filter - DEBUG - input: interferogram/topophase.flat
# 2022-01-13 11:35:31,352 - isce.mroipac.filter - DEBUG - output: interferogram/filt_topophase.flat
# 2022-01-13 11:35:31,352 - isce.mroipac.filter - DEBUG - filter strength: 0.5
# 2022-01-13 11:35:31,352 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  2903  2668     0
# line:  2656
# number of lines written to file: 2672
# Rescaling magnitude
# line:  2667GDAL close: interferogram/topophase.flat.vrt
# API close:  interferogram/filt_topophase.flat
# GDAL open (R): interferogram/filt_topophase.flat.vrt
# API open (WR): interferogram/phsig.cor
# GDAL open (R): interferogram/topophase.amp.vrt
#
#  << PS filtering >>
#
#
#  interferogram width:  2903  number of lines/patch:  3700
#  start line:        1  number of lines:    2668
#  start sample:      1  end sample:         2903
#  wisdomFile, length =            0
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  1
#
#  PATCH:   1   starting line:     0    lines read: 2668
#  starting output line:    1   ending output line: 2668
#
# *** Normal Completion  ***
#
# GDAL close: interferogram/filt_topophase.flat.vrt
# API close:  interferogram/phsig.cor
# API open (R): interferogram/phsig.cor
# API close:  interferogram/phsig.cor
# GDAL close: interferogram/topophase.amp.vrt
# Dumping the application's pickle object _insar to file  PICKLE/filter
# The remaining steps are (in order):  ['filter_low_band', 'filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']
# Running step filter_low_band
# 2022-01-13 11:35:41,590 - isce.insar.runFilter - INFO - Applying power-spectral filter
# 2022-01-13 11:35:41,590 - isce.insar.runFilter - INFO - Filtering the low-band interferogram
# GDAL open (R): interferogram/lowBand/topophase.flat.vrt
# API open (WR): interferogram/lowBand/filt_topophase.flat
# 2022-01-13 11:35:41,601 - isce.mroipac.filter - DEBUG - width: 2903
# 2022-01-13 11:35:41,601 - isce.mroipac.filter - DEBUG - length: 2668
# 2022-01-13 11:35:41,601 - isce.mroipac.filter - DEBUG - input: interferogram/lowBand/topophase.flat
# 2022-01-13 11:35:41,601 - isce.mroipac.filter - DEBUG - output: interferogram/lowBand/filt_topophase.flat
# 2022-01-13 11:35:41,601 - isce.mroipac.filter - DEBUG - filter strength: 0.5
# 2022-01-13 11:35:41,601 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  2903  2668     0
# line:  2656
# number of lines written to file: 2672
# Rescaling magnitude
# line:  2667GDAL close: interferogram/lowBand/topophase.flat.vrt
# API close:  interferogram/lowBand/filt_topophase.flat
# GDAL open (R): interferogram/lowBand/filt_topophase.flat.vrt
# API open (WR): interferogram/lowBand/phsig.cor
# GDAL open (R): interferogram/lowBand/topophase.amp.vrt
#
#  << PS filtering >>
#
#
#  interferogram width:  2903  number of lines/patch:  3700
#  start line:        1  number of lines:    2668
#  start sample:      1  end sample:         2903
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  1
#
#  PATCH:   1   starting line:     0    lines read: 2668
#  starting output line:    1   ending output line: 2668
#
# *** Normal Completion  ***
#
# GDAL close: interferogram/lowBand/filt_topophase.flat.vrt
# API close:  interferogram/lowBand/phsig.cor
# API open (R): interferogram/lowBand/phsig.cor
# API close:  interferogram/lowBand/phsig.cor
# GDAL close: interferogram/lowBand/topophase.amp.vrt
# Dumping the application's pickle object _insar to file  PICKLE/filter_low_band
# The remaining steps are (in order):  ['filter_high_band', 'unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']
# Running step filter_high_band
# 2022-01-13 11:35:51,541 - isce.insar.runFilter - INFO - Applying power-spectral filter
# 2022-01-13 11:35:51,541 - isce.insar.runFilter - INFO - Filtering the high-band interferogram
# GDAL open (R): interferogram/highBand/topophase.flat.vrt
# API open (WR): interferogram/highBand/filt_topophase.flat
# 2022-01-13 11:35:51,552 - isce.mroipac.filter - DEBUG - width: 2903
# 2022-01-13 11:35:51,553 - isce.mroipac.filter - DEBUG - length: 2668
# 2022-01-13 11:35:51,553 - isce.mroipac.filter - DEBUG - input: interferogram/highBand/topophase.flat
# 2022-01-13 11:35:51,553 - isce.mroipac.filter - DEBUG - output: interferogram/highBand/filt_topophase.flat
# 2022-01-13 11:35:51,553 - isce.mroipac.filter - DEBUG - filter strength: 0.5
# 2022-01-13 11:35:51,553 - isce.mroipac.filter - INFO - Filtering interferogram
# array width, height, offset:  2903  2668     0
# line:  2656
# number of lines written to file: 2672
# Rescaling magnitude
# line:  2667GDAL close: interferogram/highBand/topophase.flat.vrt
# API close:  interferogram/highBand/filt_topophase.flat
# GDAL open (R): interferogram/highBand/filt_topophase.flat.vrt
# API open (WR): interferogram/highBand/phsig.cor
# GDAL open (R): interferogram/highBand/topophase.amp.vrt
#
#  << PS filtering >>
#
#
#  interferogram width:  2903  number of lines/patch:  3700
#  start line:        1  number of lines:    2668
#  start sample:      1  end sample:         2903
#
#  azimuth buffer size:                             3700
#  overlap between azimuth patches:                  200
#  total overlap between azimuth patches:            264
#  offset in overlap region for phase  bootstrap:    132
#  lines to increment for the next patch:           3436
#  number of patches:                                  1
#
#  PATCH:   1   starting line:     0    lines read: 2668
#  starting output line:    1   ending output line: 2668
#
# *** Normal Completion  ***
#
# GDAL close: interferogram/highBand/filt_topophase.flat.vrt
# API close:  interferogram/highBand/phsig.cor
# API open (R): interferogram/highBand/phsig.cor
# API close:  interferogram/highBand/phsig.cor
# GDAL close: interferogram/highBand/topophase.amp.vrt
# Dumping the application's pickle object _insar to file  PICKLE/filter_high_band
# The remaining steps are (in order):  ['unwrap', 'unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']

# %% [markdown]
# Note that the three interferograms (full- low- and high-bands) visually look similar.

# %%
from osgeo import gdal
import matplotlib.pyplot as plt

ds = gdal.Open("interferogram/filt_topophase.flat", gdal.GA_ReadOnly)
igram_full_band = ds.GetRasterBand(1).ReadAsArray()
ds = None

ds = gdal.Open("interferogram/lowBand/filt_topophase.flat", gdal.GA_ReadOnly)
igram_low_band = ds.GetRasterBand(1).ReadAsArray()
ds = None

ds = gdal.Open("interferogram/highBand/filt_topophase.flat", gdal.GA_ReadOnly)
igram_high_band = ds.GetRasterBand(1).ReadAsArray()
ds = None

fig = plt.figure(figsize=(18, 16))

ax = fig.add_subplot(1,3,1)
ax.imshow(np.angle(igram_full_band), cmap='hsv')
ax.set_title("full-band")
ax.set_axis_off()

ax = fig.add_subplot(1,3,2)
ax.imshow(np.angle(igram_low_band), cmap='hsv')
ax.set_title("low-band")
ax.set_axis_off()

ax = fig.add_subplot(1,3,3)
ax.imshow(np.angle(igram_high_band), cmap='hsv')
ax.set_title("high-band")
#ax.set_axis_off()
# Out:
# Text(0.5, 1.0, 'high-band')

# %% [markdown]
# However, due to small difference between the center frequency of the sub-bands full-bands, there is small difference among the three interferograms. See the difference between the full-band and low-band interferograms:

# %%
difference_full_low = igram_full_band*np.conjugate(igram_low_band)
fig = plt.figure(figsize=(18, 16))

ax = fig.add_subplot(1,3,1)
cax = ax.imshow(np.angle(difference_full_low), cmap='jet', vmin = -2.5, vmax =-2)
ax.set_title("difference of full-band and low band interferograms")
ax.set_axis_off()
cbar = fig.colorbar(cax, ticks=[-2.5,-2], orientation='horizontal')

igram_low_band = None
igram_full_band = None
igram_high_band = None
difference_full_low = None

# %% [markdown]
# ### unwrap_low_band, unwrap_high_band

# %% [markdown]
# unwrap the full-band, low-band and high-band interferograms

# %%
# !stripmapApp.py stripmapApp.xml --start=unwrap  --end=unwrap_high_band
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:36:04,442 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:36:04,443 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:36:04,463 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step unwrap
# igramSpectrum:  full
#
# snaphu v1.4.2
# Reading wrapped phase from file interferogram/filt_topophase.flat
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file interferogram/phsig.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file interferogram/filt_topophase.unw
# Growing connected components on second pass
#
# snaphu v1.4.2
# Reading unwrapped phase from file interferogram/filt_topophase.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file interferogram/phsig.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file interferogram/filt_topophase.unw.conncomp
# API open (R): interferogram/filt_topophase.unw
# API close:  interferogram/filt_topophase.unw
# API open (R): interferogram/filt_topophase.unw.conncomp
# API close:  interferogram/filt_topophase.unw.conncomp
# Dumping the application's pickle object _insar to file  PICKLE/unwrap
# The remaining steps are (in order):  ['unwrap_low_band', 'unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']
# Running step unwrap_low_band
# igramSpectrum:  low
#
# snaphu v1.4.2
# Reading wrapped phase from file interferogram/lowBand/filt_topophase.flat
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file interferogram/lowBand/phsig.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file interferogram/lowBand/filt_topophase.unw
# Growing connected components on second pass
#
# snaphu v1.4.2
# Reading unwrapped phase from file interferogram/lowBand/filt_topophase.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file interferogram/lowBand/phsig.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file interferogram/lowBand/filt_topophase.unw.conncomp
# API open (R): interferogram/lowBand/filt_topophase.unw
# API close:  interferogram/lowBand/filt_topophase.unw
# API open (R): interferogram/lowBand/filt_topophase.unw.conncomp
# API close:  interferogram/lowBand/filt_topophase.unw.conncomp
# Dumping the application's pickle object _insar to file  PICKLE/unwrap_low_band
# The remaining steps are (in order):  ['unwrap_high_band', 'ionosphere', 'geocode', 'geocodeoffsets', 'endup']
# Running step unwrap_high_band
# igramSpectrum:  high
#
# snaphu v1.4.2
# Reading wrapped phase from file interferogram/highBand/filt_topophase.flat
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file interferogram/highBand/phsig.cor
# Calculating smooth-solution cost parameters
# Initializing flows with MCF algorithm
# Integrating phase
# Writing output to file interferogram/highBand/filt_topophase.unw
# Growing connected components on second pass
#
# snaphu v1.4.2
# Reading unwrapped phase from file interferogram/highBand/filt_topophase.unw
# No weight file specified.  Assuming uniform weights
# Reading correlation data from file interferogram/highBand/phsig.cor
# Calculating smooth-solution cost parameters
# Growing connected component mask
# Writing connected components to file interferogram/highBand/filt_topophase.unw.conncomp
# API open (R): interferogram/highBand/filt_topophase.unw
# API close:  interferogram/highBand/filt_topophase.unw
# API open (R): interferogram/highBand/filt_topophase.unw.conncomp
# API close:  interferogram/highBand/filt_topophase.unw.conncomp
# Dumping the application's pickle object _insar to file  PICKLE/unwrap_high_band
# The remaining steps are (in order):  ['ionosphere', 'geocode', 'geocodeoffsets', 'endup']

# %% [markdown]
# ### ionosphere

# %% [markdown]
# This step, uses the low-band and high-bamd unwrapped interferograms to estimate the dispersive and non-dispersive phase components. The disperive phase is related to the ionosphere's TEC variation.

# %%
# !stripmapApp.py stripmapApp.xml --start=ionosphere --end=ionosphere
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:50:26,120 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:50:26,121 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:50:26,141 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step ionosphere
# incidence angle at the middle of the swath:  30.768479575844513
# Ground range resolution at the middle of the swath:  11.76755089528644
# imageMath.py -e="3.0119124769050574e-08*(a_1*1244799759.747266-(b_1+2.0*PI)*1228199759.7462432)" --a=interferogram/lowBand/filt_topophase.unw --b=interferogram/highBand/filt_topophase.unw -o ionosphere/dispersive.bil -t float32 -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float32', equation='3.0119124769050574e-08*(a_1*1244799759.747266-(b_1+2.0*PI)*1228199759.7462432)', hh=None, noxml=False, out='ionosphere/dispersive.bil', scheme='BIL')
# files:  ['--a=interferogram/lowBand/filt_topophase.unw', '--b=interferogram/highBand/filt_topophase.unw']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/dispersive.bil.vrt
# GDAL close: ionosphere/dispersive.bil.vrt
# imageMath.py -e="3.012048192585492e-08*((a_1+2.0*PI)*1244799759.747266-(b_1)*1228199759.7462432)" --a=interferogram/highBand/filt_topophase.unw --b=interferogram/lowBand/filt_topophase.unw -o ionosphere/nondispersive.bil -t float32 -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float32', equation='3.012048192585492e-08*((a_1+2.0*PI)*1244799759.747266-(b_1)*1228199759.7462432)', hh=None, noxml=False, out='ionosphere/nondispersive.bil', scheme='BIL')
# files:  ['--a=interferogram/highBand/filt_topophase.unw', '--b=interferogram/lowBand/filt_topophase.unw']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/nondispersive.bil.vrt
# GDAL close: ionosphere/nondispersive.bil.vrt
# generating a mask based on .conncomp files
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='byte', equation='(a>0)*(b>0)', hh=None, noxml=False, out='ionosphere/mask.bil', scheme='BIL')
# files:  ['--a=interferogram/lowBand/filt_topophase.unw.conncomp', '--b=interferogram/highBand/filt_topophase.unw.conncomp']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/mask.bil.vrt
# GDAL close: ionosphere/mask.bil.vrt
# imageMath.py -e="sqrt(1-a**2)/a/sqrt(2.0*24)" --a=interferogram/lowBand/phsig.cor -o interferogram/lowBand/filt_topophase.flat.sig -t float -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float', equation='sqrt(1-a**2)/a/sqrt(2.0*24)', hh=None, noxml=False, out='interferogram/lowBand/filt_topophase.flat.sig', scheme='BIL')
# files:  ['--a=interferogram/lowBand/phsig.cor']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# <string>:1: RuntimeWarning: divide by zero encountered in true_divide
# GDAL open (R): interferogram/lowBand/filt_topophase.flat.sig.vrt
# GDAL close: interferogram/lowBand/filt_topophase.flat.sig.vrt
# imageMath.py -e="sqrt(1-a**2)/a/sqrt(2.0*24)" --a=interferogram/highBand/phsig.cor -o interferogram/highBand/filt_topophase.flat.sig -t float -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float', equation='sqrt(1-a**2)/a/sqrt(2.0*24)', hh=None, noxml=False, out='interferogram/highBand/filt_topophase.flat.sig', scheme='BIL')
# files:  ['--a=interferogram/highBand/phsig.cor']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# <string>:1: RuntimeWarning: divide by zero encountered in true_divide
# GDAL open (R): interferogram/highBand/filt_topophase.flat.sig.vrt
# GDAL close: interferogram/highBand/filt_topophase.flat.sig.vrt
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float', equation='sqrt((3.0119124769050574e-08**2)*(1228199759.7462432**2)*(a**2) + (3.0119124769050574e-08**2)*(1244799759.747266**2)*(b**2))', hh=None, noxml=False, out='ionosphere/dispersive.bil.sig', scheme='BIL')
# files:  ['--a=interferogram/lowBand/filt_topophase.flat.sig', '--b=interferogram/highBand/filt_topophase.flat.sig']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/dispersive.bil.sig.vrt
# GDAL close: ionosphere/dispersive.bil.sig.vrt
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float', equation='sqrt((3.012048192585492e-08**2)*(1228199759.7462432**2)*(a**2) + (3.012048192585492e-08**2)*(1244799759.747266**2)*(b**2))', hh=None, noxml=False, out='ionosphere/nondispersive.bil.sig', scheme='BIL')
# files:  ['--a=interferogram/lowBand/filt_topophase.flat.sig', '--b=interferogram/highBand/filt_topophase.flat.sig']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/nondispersive.bil.sig.vrt
# GDAL close: ionosphere/nondispersive.bil.sig.vrt
# masking the data
# Filling the holes with nearest neighbor interpolation
# Low pass Gaussian filtering the interpolated data
# iteration:  0  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  1  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  2  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  3  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  4  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# masking the data
# Filling the holes with nearest neighbor interpolation
# Low pass Gaussian filtering the interpolated data
# iteration:  0  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  1  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  2  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  3  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  4  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# imageMath.py -e="round(((a_1+(2.0*PI)) - (b_1) - (2.0*24900000.001534563/3.0/1236499759.7467546)*c + (2.0*24900000.001534563/3.0/1236499759.7467546)*f )/2.0/PI)" --a=interferogram/highBand/filt_topophase.unw --b=interferogram/lowBand/filt_topophase.unw --c=ionosphere/nondispersive.bil.filt --f=ionosphere/dispersive.bil.filt  -o ionosphere/dJumps.bil -t float32 -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float32', equation='round(((a_1+(2.0*PI)) - (b_1) - (2.0*24900000.001534563/3.0/1236499759.7467546)*c + (2.0*24900000.001534563/3.0/1236499759.7467546)*f )/2.0/PI)', hh=None, noxml=False, out='ionosphere/dJumps.bil', scheme='BIL')
# files:  ['--a=interferogram/highBand/filt_topophase.unw', '--b=interferogram/lowBand/filt_topophase.unw', '--c=ionosphere/nondispersive.bil.filt', '--f=ionosphere/dispersive.bil.filt']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/dJumps.bil.vrt
# GDAL close: ionosphere/dJumps.bil.vrt
# imageMath.py -e="round(((a_1 ) + (b_1+(2.0*PI)) - 2.0*c - 2.0*f )/4.0/PI - g/2)" --a=interferogram/lowBand/filt_topophase.unw --b=interferogram/highBand/filt_topophase.unw --c=ionosphere/nondispersive.bil.filt --f=ionosphere/dispersive.bil.filt --g=ionosphere/dJumps.bil -o ionosphere/mJumps.bil -t float32 -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float32', equation='round(((a_1 ) + (b_1+(2.0*PI)) - 2.0*c - 2.0*f )/4.0/PI - g/2)', hh=None, noxml=False, out='ionosphere/mJumps.bil', scheme='BIL')
# files:  ['--a=interferogram/lowBand/filt_topophase.unw', '--b=interferogram/highBand/filt_topophase.unw', '--c=ionosphere/nondispersive.bil.filt', '--f=ionosphere/dispersive.bil.filt', '--g=ionosphere/dJumps.bil']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/mJumps.bil.vrt
# GDAL close: ionosphere/mJumps.bil.vrt
# imageMath.py -e="3.0119124769050574e-08*((a_1-2*PI*c)*1244799759.747266-(b_1+(2.0*PI)-2*PI*(c+f))*1228199759.7462432)" --a=interferogram/lowBand/filt_topophase.unw --b=interferogram/highBand/filt_topophase.unw --c=ionosphere/mJumps.bil --f=ionosphere/dJumps.bil -o ionosphere/dispersive.bil.unwCor -t float32 -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float32', equation='3.0119124769050574e-08*((a_1-2*PI*c)*1244799759.747266-(b_1+(2.0*PI)-2*PI*(c+f))*1228199759.7462432)', hh=None, noxml=False, out='ionosphere/dispersive.bil.unwCor', scheme='BIL')
# files:  ['--a=interferogram/lowBand/filt_topophase.unw', '--b=interferogram/highBand/filt_topophase.unw', '--c=ionosphere/mJumps.bil', '--f=ionosphere/dJumps.bil']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/dispersive.bil.unwCor.vrt
# GDAL close: ionosphere/dispersive.bil.unwCor.vrt
# imageMath.py -e="3.012048192585492e-08*((a_1+(2.0*PI)-2*PI*c)*1244799759.747266-(b_1-2*PI*(c+f))*1228199759.7462432)" --a=interferogram/highBand/filt_topophase.unw --b=interferogram/lowBand/filt_topophase.unw --c=ionosphere/mJumps.bil --f=ionosphere/dJumps.bil -o ionosphere/nondispersive.bil.unwCor -t float32 -s BIL
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# args:  Namespace(debug=False, dtype='float32', equation='3.012048192585492e-08*((a_1+(2.0*PI)-2*PI*c)*1244799759.747266-(b_1-2*PI*(c+f))*1228199759.7462432)', hh=None, noxml=False, out='ionosphere/nondispersive.bil.unwCor', scheme='BIL')
# files:  ['--a=interferogram/highBand/filt_topophase.unw', '--b=interferogram/lowBand/filt_topophase.unw', '--c=ionosphere/mJumps.bil', '--f=ionosphere/dJumps.bil']
# /home/gareth/pkgs/isce2/applications/imageMath.py:418: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dataDict['COL'] = np.arange(iMath['width'], dtype=np.float)
# GDAL open (R): ionosphere/nondispersive.bil.unwCor.vrt
# GDAL close: ionosphere/nondispersive.bil.unwCor.vrt
# masking the data
# Filling the holes with nearest neighbor interpolation
# Low pass Gaussian filtering the interpolated data
# iteration:  0  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  1  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  2  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  3  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  4  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# masking the data
# Filling the holes with nearest neighbor interpolation
# Low pass Gaussian filtering the interpolated data
# iteration:  0  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  1  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  2  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  3  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# iteration:  4  of  5
# masking the interpolated and filtered data
# Filling the holes with nearest neighbor interpolation of the filtered data from previous step
# Replace the valid pixels with original unfiltered data
# Dumping the application's pickle object _insar to file  PICKLE/ionosphere
# The remaining steps are (in order):  ['geocode', 'geocodeoffsets', 'endup']

# %% [markdown]
# The following plot shows the estimated dispersive and non-dispersive phase components.

# %%
from osgeo import gdal
import matplotlib.pyplot as plt
def rewrap(data):
    return data-np.round(data/2./np.pi)*2*np.pi
    
    
ds = gdal.Open("ionosphere/dispersive.bil.filt", gdal.GA_ReadOnly)
iono = ds.GetRasterBand(1).ReadAsArray()
ds = None

ds = gdal.Open("ionosphere/nondispersive.bil.filt", gdal.GA_ReadOnly)
non_dispersive = ds.GetRasterBand(1).ReadAsArray()
ds = None

ds = gdal.Open("ionosphere/mask.bil", gdal.GA_ReadOnly)
mask = ds.GetRasterBand(1).ReadAsArray()
ds = None

fig = plt.figure(figsize=(18, 16))

ax = fig.add_subplot(1,3,1)
ax.imshow(rewrap(iono)*mask, cmap='hsv')
ax.set_title("dispersive (ionospheric phase)")
ax.set_axis_off()

ax = fig.add_subplot(1,3,2)
ax.imshow(rewrap(non_dispersive)*mask, cmap='hsv')
ax.set_title("non-dispersive")
ax.set_axis_off()

iono = None
non_dispersive = None

# %% [markdown]
# <br>
# <div class="alert alert-info">
# <b>Note :</b>
# stripmapApp does not correct the interferogram for ionospheric phase. However, the corrected interferogram can be easily obtained by removing the estimated dispersive phase from the full-band interferogram.
#
# </div>

# %%
ds = gdal.Open("interferogram/filt_topophase.unw", gdal.GA_ReadOnly)
igram = ds.GetRasterBand(2).ReadAsArray()
ds = None

ds = gdal.Open("ionosphere/dispersive.bil.filt", gdal.GA_ReadOnly)
iono = ds.GetRasterBand(1).ReadAsArray()
ds = None

igram_iono_corrected = igram - iono

fig = plt.figure(figsize=(18, 16))

ax = fig.add_subplot(1,3,1)
ax.imshow(rewrap(igram), cmap='hsv')
ax.set_title("before ionospheric phase correction")
ax.set_axis_off()

ax = fig.add_subplot(1,3,2)
ax.imshow(rewrap(igram_iono_corrected)*mask, cmap='hsv')
ax.set_title("after ionospheric phase correction")
ax.set_axis_off()

iono = None
igram = None
igram_iono_corrected = None

# %% [markdown]
# ### geocoding

# %% [markdown]
# By runing the geocode step, the interferogram, the dispersive phase and the mask in the ionosphere folder is geocoded.

# %%
# !stripmapApp.py stripmapApp.xml --start=geocode  --end=geocode
# Out:
# This is the Open Source version of ISCE.
# Some of the workflows depend on a separate licensed package.
# To obtain the licensed package, please make a request for ISCE
# through the website: https://download.jpl.nasa.gov/ops/request/index.cfm.
# Alternatively, if you are a member, or can become a member of WinSAR
# you may be able to obtain access to a version of the licensed sofware at
# https://winsar.unavco.org/software/isce
# 2022-01-13 11:51:16,250 - isce.insar - INFO - ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# ISCE VERSION = 2.5.1, RELEASE_SVN_REVISION = ,RELEASE_DATE = 20210305, CURRENT_SVN_REVISION =
# 2022-01-13 11:51:16,251 - root - INFO - reference sensor not provided explicitly, using common sensor
# 2022-01-13 11:51:16,271 - root - INFO - secondary sensor not provided explicitly, using common sensor
# do_unwrap  True
# Step processing
# Running step geocode
# 2022-01-13 11:51:16,314 - isce.topsinsar.runGeocode - INFO - Geocoding Image
# Number of products to geocode:  10
# incidence angle at the middle of the swath:  30.768479575844513
# Ground range resolution at the middle of the swath:  11.76755089528644
# Polynomial Order: 0 - by - 0
# 0
# Polynomial Order: 0 - by - 0
# 0
# Output:  interferogram/topophase.flat.geo
# API open (WR): dem.crop
# API open (WR): interferogram/topophase.flat.geo
# GDAL open (R): interferogram/topophase.flat.vrt
# GDAL open (R): demLat_S09_S07_Lon_E124_E126.dem.wgs84.vrt
#  Using Sinc interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Sinc Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2154382
#  Number of pixels with valid data:        5033511
#  elapsed time =    3.17187500      seconds
# GDAL close: demLat_S09_S07_Lon_E124_E126.dem.wgs84.vrt
# GDAL close: interferogram/topophase.flat.vrt
# API close:  dem.crop
# API close:  interferogram/topophase.flat.geo
# API open (R): interferogram/topophase.flat.geo
# API close:  interferogram/topophase.flat.geo
# Writing geotrans to VRT for interferogram/topophase.flat.geo
# Output:  interferogram/filt_topophase.flat.geo
# API open (WR): dem.crop
# API open (WR): interferogram/filt_topophase.flat.geo
# GDAL open (R): interferogram/filt_topophase.flat.vrt
# GDAL open (R): demLat_S09_S07_Lon_E124_E126.dem.wgs84.vrt
#  Using Sinc interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Sinc Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2154720
#  Number of pixels with valid data:        5033059
#  elapsed time =    3.15625000      seconds
# GDAL close: interferogram/filt_topophase.flat.vrt
# API close:  dem.crop
# API close:  interferogram/filt_topophase.flat.geo
# API open (R): interferogram/filt_topophase.flat.geo
# API close:  interferogram/filt_topophase.flat.geo
# Writing geotrans to VRT for interferogram/filt_topophase.flat.geo
# Output:  interferogram/phsig.cor.geo
# API open (WR): dem.crop
# API open (WR): interferogram/phsig.cor.geo
# GDAL open (R): interferogram/phsig.cor.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2136846
#  Number of pixels with valid data:        4944346
#  elapsed time =    2.89453125      seconds
# GDAL close: interferogram/phsig.cor.vrt
# API close:  dem.crop
# API close:  interferogram/phsig.cor.geo
# API open (R): interferogram/phsig.cor.geo
# API close:  interferogram/phsig.cor.geo
# Writing geotrans to VRT for interferogram/phsig.cor.geo
# Output:  interferogram/topophase.cor.geo
# API open (WR): dem.crop
# API open (WR): interferogram/topophase.cor.geo
# GDAL open (R): interferogram/topophase.cor.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2134487
#  Number of pixels with valid data:        4950289
#  elapsed time =    2.96093750      seconds
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2135757
#  Number of pixels with valid data:        4930735
#  elapsed time =    2.87109375      seconds
# GDAL close: interferogram/topophase.cor.vrt
# API close:  dem.crop
# API close:  interferogram/topophase.cor.geo
# API open (R): interferogram/topophase.cor.geo
# API close:  interferogram/topophase.cor.geo
# Writing geotrans to VRT for interferogram/topophase.cor.geo
# Output:  interferogram/filt_topophase.unw.geo
# API open (WR): dem.crop
# API open (WR): interferogram/filt_topophase.unw.geo
# GDAL open (R): interferogram/filt_topophase.unw.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2122404
#  Number of pixels with valid data:        4922309
#  elapsed time =    2.91015625      seconds
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2136028
#  Number of pixels with valid data:        4950285
#  elapsed time =    2.89062500      seconds
# GDAL close: interferogram/filt_topophase.unw.vrt
# API close:  dem.crop
# API close:  interferogram/filt_topophase.unw.geo
# API open (R): interferogram/filt_topophase.unw.geo
# API close:  interferogram/filt_topophase.unw.geo
# Writing geotrans to VRT for interferogram/filt_topophase.unw.geo
# Output:  interferogram/filt_topophase.unw.conncomp.geo
# API open (WR): dem.crop
# API open (WR): interferogram/filt_topophase.unw.conncomp.geo
# GDAL open (R): interferogram/filt_topophase.unw.conncomp.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2133911
#  Number of pixels with valid data:        4937616
#  elapsed time =    2.87890625      seconds
# GDAL close: interferogram/filt_topophase.unw.conncomp.vrt
# API close:  dem.crop
# API close:  interferogram/filt_topophase.unw.conncomp.geo
# API open (R): interferogram/filt_topophase.unw.conncomp.geo
# API close:  interferogram/filt_topophase.unw.conncomp.geo
# Writing geotrans to VRT for interferogram/filt_topophase.unw.conncomp.geo
# Output:  geometry/los.rdr.geo
# API open (WR): dem.crop
# API open (WR): geometry/los.rdr.geo
# GDAL open (R): geometry/los.rdr.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2136409
#  Number of pixels with valid data:        4919990
#  elapsed time =    2.91796875      seconds
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2128674
#  Number of pixels with valid data:        4875512
#  elapsed time =    2.88671875      seconds
# GDAL close: geometry/los.rdr.vrt
# API close:  dem.crop
# API close:  geometry/los.rdr.geo
# API open (R): geometry/los.rdr.geo
# API close:  geometry/los.rdr.geo
# Writing geotrans to VRT for geometry/los.rdr.geo
# Output:  ionosphere/dispersive.bil.unwCor.filt.geo
# API open (WR): dem.crop
# API open (WR): ionosphere/dispersive.bil.unwCor.filt.geo
# GDAL open (R): ionosphere/dispersive.bil.unwCor.filt.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2133327
#  Number of pixels with valid data:        4932154
#  elapsed time =    2.90234375      seconds
# GDAL close: ionosphere/dispersive.bil.unwCor.filt.vrt
# API close:  dem.crop
# API close:  ionosphere/dispersive.bil.unwCor.filt.geo
# API open (R): ionosphere/dispersive.bil.unwCor.filt.geo
# API close:  ionosphere/dispersive.bil.unwCor.filt.geo
# Writing geotrans to VRT for ionosphere/dispersive.bil.unwCor.filt.geo
# Output:  ionosphere/nondispersive.bil.unwCor.filt.geo
# API open (WR): dem.crop
# API open (WR): ionosphere/nondispersive.bil.unwCor.filt.geo
# GDAL open (R): ionosphere/nondispersive.bil.unwCor.filt.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2133022
#  Number of pixels with valid data:        4937192
#  elapsed time =    2.89062500      seconds
# GDAL close: ionosphere/nondispersive.bil.unwCor.filt.vrt
# API close:  dem.crop
# API close:  ionosphere/nondispersive.bil.unwCor.filt.geo
# API open (R): ionosphere/nondispersive.bil.unwCor.filt.geo
# API close:  ionosphere/nondispersive.bil.unwCor.filt.geo
# Writing geotrans to VRT for ionosphere/nondispersive.bil.unwCor.filt.geo
# Output:  ionosphere/mask.bil.geo
# API open (WR): dem.crop
# API open (WR): ionosphere/mask.bil.geo
# GDAL open (R): ionosphere/mask.bil.vrt
#  Using nearest neighbor interpolation
#  threads           8
#  Starting Acquisition time:    12167.245272000000
#  Stop Acquisition time:    12177.239790748032
#  Azimuth line spacing in secs:    3.7474760959999233E-003
#  Near Range in m:    713574.29126671783
#  Far  Range in m:    750934.05931248749
#  Range sample spacing in m:    12.873800153607743
#  Input Lines:         2668
#  Input Width:         2903
#  reading interferogram ...
#  Geocoded Lines:          2704
#  Geocoded Samples:        2774
#  Initializing Nearest Neighbor Interpolator
#  geocoding on            8  threads...
#  Number of pixels with outside DEM:             0
#  Number of pixels outside the image:      2118861
#  Number of pixels with valid data:        4933831
#  elapsed time =    2.99218750      seconds
# GDAL close: ionosphere/mask.bil.vrt
# API close:  dem.crop
# API close:  ionosphere/mask.bil.geo
# API open (R): ionosphere/mask.bil.geo
# API close:  ionosphere/mask.bil.geo
# Writing geotrans to VRT for ionosphere/mask.bil.geo
# 2022-01-13 11:51:55,637 - isce.topsinsar.runGeocode - INFO -
# ####################################################################################################
#     runGeocode
# ----------------------------------------------------------------------------------------------------
# geocode.Azimuth looks = 8
# geocode.Dem Used = demLat_S09_S07_Lon_E124_E126.dem.wgs84
# geocode.East = 125.26
# geocode.Geocoding:  = ionosphere/mask.bil
# geocode.Length = 2668
# geocode.North = -7.998055555555555
# geocode.Output file:  = ionosphere/mask.bil.geo
# geocode.Range looks = 3
# geocode.South = -8.749166666666667
# geocode.West = 124.48944444444444
# geocode.Width = 2903
# ####################################################################################################
# Dumping the application's pickle object _insar to file  PICKLE/geocode
# The remaining steps are (in order):  ['geocodeoffsets', 'endup']

# %% [markdown]
# The follwoing plot comapres the geocoded interferogram before and after ionospheric phase estimation.

# %%
# reading the multi-looked wrapped interferogram
ds = gdal.Open("/scratch/alor_2015_dsc_III/interferogram/filt_topophase.unw.geo", gdal.GA_ReadOnly)
igram = ds.GetRasterBand(2).ReadAsArray()
ds = None

ds = gdal.Open("/scratch/alor_2015_dsc_III/ionosphere/dispersive.bil.unwCor.filt.geo", gdal.GA_ReadOnly)
iono = ds.GetRasterBand(1).ReadAsArray()
ds = None

ds = gdal.Open("/scratch/alor_2015_dsc_III/ionosphere/mask.bil.geo", gdal.GA_ReadOnly)
mask = ds.GetRasterBand(1).ReadAsArray()
#ds = None

# from eyeballing the initial output in mdx
#phaseshift=230
phaseshift=50

igram_iono_corrected = (igram - iono + phaseshift)*mask

fig = plt.figure(figsize=(14,12))

ax = fig.add_subplot(1,2,1)

cax = ax.imshow(rewrap(igram), cmap = 'hsv')
ax.set_title("geocoded unwrapped (before ionospheric phase correction)")
ax.set_axis_off()

ax = fig.add_subplot(1,2,2)
cax = ax.imshow(rewrap(igram_iono_corrected), cmap = 'hsv')
ax.set_title("geocoded unwrapped (after ionospheric phase correction)")
ax.set_axis_off()

# some stuff I found on the internet

# i found these in the filt_topophase.unw.geo.vrt file
cols=2814
rows=2705

driver = gdal.GetDriverByName("ENVI")
outdata = driver.Create('filt_topophase.unw-iono_correction.r4', cols, rows, 1, gdal.GDT_Float32)
outdata.SetGeoTransform(ds.GetGeoTransform())##sets same geotransform as input
outdata.SetProjection(ds.GetProjection())##sets same projection as input
outdata.GetRasterBand(1).WriteArray(igram_iono_corrected)
outdata.GetRasterBand(1).SetNoDataValue(0)##if you want these values transparent
outdata.FlushCache() ##saves to disk!!


igram = None
iono = None
igram_iono_corrected = None
mask = None

# %%
# if we want it to write a GeoTiff

# reading the multi-looked wrapped interferogram
ds = gdal.Open("/scratch/alor_2015_dsc_III/interferogram/filt_topophase.unw.geo", gdal.GA_ReadOnly)
igram = ds.GetRasterBand(2).ReadAsArray()
ds = None

ds = gdal.Open("/scratch/alor_2015_dsc_III/ionosphere/dispersive.bil.unwCor.filt.geo", gdal.GA_ReadOnly)
iono = ds.GetRasterBand(1).ReadAsArray()
ds = None

ds = gdal.Open("/scratch/alor_2015_dsc_III/ionosphere/mask.bil.geo", gdal.GA_ReadOnly)
mask = ds.GetRasterBand(1).ReadAsArray()
#ds = None

# from eyeballing the initial output in mdx -is this dispersive.bil.unwCor.filt.geo
#phaseshift=230
#phaseshift=50
phaseshift=-800

igram_iono_corrected = (igram - iono + phaseshift)*mask

# some stuff I found on the internet

# i found these in the filt_topophase.unw.geo.vrt file
cols=2774
rows=2704

driver = gdal.GetDriverByName("GTiff")
outdata = driver.Create('/scratch/alor_2015_dsc_III/filt_topophase.unw-iono_correction.tif', cols, rows, 1, gdal.GDT_Float32)
outdata.SetGeoTransform(ds.GetGeoTransform())##sets same geotransform as input
outdata.SetProjection(ds.GetProjection())##sets same projection as input
outdata.GetRasterBand(1).WriteArray(igram_iono_corrected)
outdata.GetRasterBand(1).SetNoDataValue(0)##if you want these values transparent
outdata.FlushCache() ##saves to disk!!


igram = None
iono = None
igram_iono_corrected = None
mask = None

# %%
# !cat interferogram/filt_topophase.unw.geo.vrt
# Out:
# cat: interferogram/filt_topophase.unw.geo.vrt: No such file or directory

# %% [markdown]
# # Supplementary information

# %% [markdown]
# ### Low-pass filtering the estimated ionospheric phase

# %% [markdown]
# The estimated ionospheric phase from split range-spectrum method is usually noisy. Small decorrelation noise in sub-band interferograms amplifies significantly in the estimated ionospheric phase. Therefore low-pass filtering is usually necessary to reduce noise from the ionospheric noise. The default filter included in stripmapApp is an iterative low-pass filter with a gaussian kernel whose parameters can be controlled from the input xml file.

# %% [markdown]
# ```xml
# <?xml version="1.0" encoding="UTF-8"?>
# <stripmapApp>
#   <component name="insar">
#     <property name="sensor name">ALOS</property>
#     <component name="reference">
#         <catalog>reference.xml</catalog>
#     </component>
#     <component name="secondary">
#         <catalog>secondary.xml</catalog>
#     </component>
#
#     <property name="demFilename">
#         <value>demLat_N18_N21_Lon_W156_W154.dem.wgs84</value>
#     </property>
#
#     <property name="unwrapper name">icu</property>
#
#
#     <property name="do dispersive">True</property>
#
#     <property name="dispersive filter kernel x-size">800</property>
#     <property name="dispersive filter kernel y-size">800</property>
#     <property name="dispersive filter kernel sigma_x">100</property>
#     <property name="dispersive filter kernel sigma_y">100</property>
#     <property name="dispersive filter kernel rotation">0</property>
#     <property name="dispersive filter number of iterations">5</property>
#     <property name="dispersive filter mask type">coherence</property>
#     <property name="dispersive filter coherence threshold">0.6</property>
#
# </component>
# </stripmapApp>
# ```

# %% [markdown]
# ![title](docs_iono/Kernel.png)

# %% [markdown]
# ### azimuth offsets induced by high ionospheric phase gradient

# %% [markdown]
# The Doppler frequency induced by high ionospheric phase gradient introduces an extra time shift (azimuth offset) which if not accounted for causes decorrelation. This effect only is observed when ionospheric phase has a spatially high frequency component usually caused by scintillation in the equatorial belt. stripmapApp allows to account for this extra azimuth shift using the optional step "rubber_sheet", which if turned on, extra azimuth shifts are computed using amplitude cross-correlation. Here is an example showing the impact of such ionospher's induced azimuth offsets on an L-band ALOS-1 interferogram in equatorial belt.
#
# ![title](docs_iono/AzOffsets.png)
